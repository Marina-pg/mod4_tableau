# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('df_rate.csv', index_col=0)

# %%
df.head()
# Out:
#       Iso3_code               Country    Region  \
# 14664       ALB               Albania    Europe
# 14665       AND               Andorra    Europe
# 14666       ARE  United Arab Emirates      Asia
# 14667       ARG             Argentina  Americas
# 14668       ARM               Armenia      Asia
#
#                              Subregion         Indicator           Dimension  \
# 14664                  Southern Europe  Violent offences  by type of offence
# 14665                  Southern Europe  Violent offences  by type of offence
# 14666                     Western Asia  Violent offences  by type of offence
# 14667  Latin America and the Caribbean  Violent offences  by type of offence
# 14668                     Western Asia  Violent offences  by type of offence
#
#               Category    Sex    Age  Year          Unit of measurement  \
# 14664  Serious assault  Total  Total  2019  Rate per 100,000 population
# ...

# %%
df['Source'].unique()
# Out:
# array(['CTS', 'CTS/MoI', 'CTS/DATASUS', 'CTS/NSO', 'CTS/NGO', 'CTS/DMDB',
#        'CTS/PPR', 'CTS/Computed', 'Computed/CTS', 'PPR/CTS', 'MoI/CTS',
#        'MoI', 'NGO', 'DMDB', 'MNS', 'NGO/CTS', 'PPR', 'NSO'], dtype=object)

# %%
eliminar_cols = ['Iso3_code', 'Age']

# %%
df = df.drop(columns=eliminar_cols)

# %%
df.head(1)
# Out:
#        Country  Region        Subregion         Indicator           Dimension  \
# 14664  Albania  Europe  Southern Europe  Violent offences  by type of offence
#
#               Category    Sex  Year          Unit of measurement        VALUE  \
# 14664  Serious assault  Total  2019  Rate per 100,000 population  5,497786271
#
#       Source
# 14664    CTS

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Country                0.0
# Region                 0.0
# Subregion              0.0
# Indicator              0.0
# Dimension              0.0
# Category               0.0
# Sex                    0.0
# Year                   0.0
# Unit of measurement    0.0
# VALUE                  0.0
# Source                 0.0
# dtype: float64

# %%
df.sample()
# Out:
#                         Country    Region         Subregion         Indicator  \
# 20556  United States of America  Americas  Northern America  Violent offences
#
#                 Dimension               Category    Sex  Year  \
# 20556  by type of offence  Sexual violence: Rape  Total  2021
#
#                Unit of measurement       VALUE Source
# 20556  Rate per 100,000 population  41,7735907    CTS

# %%
def cambiar_nombres_col(df):
    for col in df.columns:
        df.columns = df.columns.str.replace(' ', '_').str.lower()
    return df

# %%
cambiar_nombres_col(df)
# Out:
#                     country    region                        subregion  \
# 14664               Albania    Europe                  Southern Europe
# 14665               Andorra    Europe                  Southern Europe
# 14666  United Arab Emirates      Asia                     Western Asia
# 14667             Argentina  Americas  Latin America and the Caribbean
# 14668               Armenia      Asia                     Western Asia
# ...                     ...       ...                              ...
# 26109            Montenegro    Europe                  Southern Europe
# 26110             Mauritius    Africa               Sub-Saharan Africa
# 26111           El Salvador  Americas  Latin America and the Caribbean
# 26112                Serbia    Europe                  Southern Europe
# 26113              Eswatini    Africa               Sub-Saharan Africa
#
#               indicator           dimension  \
# 14664  Violent offences  by type of offence
# ...

# %%
df[df['value'] == 0].shape #es un 5.83% de los datos
# Out:
# (0, 11)

# %%
df.shape
# Out:
# (3957, 11)

# %%
df['value'] = df['value'].str.replace(',', '.')

# %%
df['value'] = df['value'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3957 entries, 14664 to 26113
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              3957 non-null   object
#  1   region               3957 non-null   object
#  2   subregion            3957 non-null   object
#  3   indicator            3957 non-null   object
#  4   dimension            3957 non-null   object
#  5   category             3957 non-null   object
#  6   sex                  3957 non-null   object
#  7   year                 3957 non-null   int64
#  8   unit_of_measurement  3957 non-null   object
#  9   value                3957 non-null   float64
#  10  source               3957 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 371.0+ KB

# %%
df['value'] = df['value'].replace(0, np.nan)

# %%
df['porcentaje'] = round(df['value']*100/100000, 4)

# %%
df.head()
# Out:
#                     country    region                        subregion  \
# 14664               Albania    Europe                  Southern Europe
# 14665               Andorra    Europe                  Southern Europe
# 14666  United Arab Emirates      Asia                     Western Asia
# 14667             Argentina  Americas  Latin America and the Caribbean
# 14668               Armenia      Asia                     Western Asia
#
#               indicator           dimension         category    sex  year  \
# 14664  Violent offences  by type of offence  Serious assault  Total  2019
# 14665  Violent offences  by type of offence  Serious assault  Total  2019
# 14666  Violent offences  by type of offence  Serious assault  Total  2019
# 14667  Violent offences  by type of offence  Serious assault  Total  2019
# 14668  Violent offences  by type of offence  Serious assault  Total  2019
#
#                unit_of_measurement       value source  porcentaje
# ...

# %%
df.to_csv('df_final.csv', index=False)
