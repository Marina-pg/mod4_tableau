# %%
import pandas as pd

# %%
df = pd.read_csv("files\data_cts_violent_and_sexual_crime(data_cts_violent_and_sexual_cri).csv", encoding="latin1", delimiter=";", header = 2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\adria\AppData\Local\Temp\ipykernel_25552\262079912.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("files\data_cts_violent_and_sexual_crime(data_cts_violent_and_sexual_cri).csv", encoding="latin1", delimiter=";", header = 2)

# %%
df.head(5)
# Out:
#   Iso3_code     Country  Region       Subregion         Indicator  \
# 0       AZE  Azerbaijan    Asia    Western Asia  Violent offences
# 1       BEL     Belgium  Europe  Western Europe  Violent offences
# 2       BGR    Bulgaria  Europe  Eastern Europe  Violent offences
# 3       BHR     Bahrain    Asia    Western Asia  Violent offences
# 4       BLR     Belarus  Europe  Eastern Europe  Violent offences
#
#             Dimension         Category    Sex    Age  Year  \
# 0  by type of offence  Serious assault  Total  Total  2003
# 1  by type of offence  Serious assault  Total  Total  2003
# 2  by type of offence  Serious assault  Total  Total  2003
# 3  by type of offence  Serious assault  Total  Total  2003
# 4  by type of offence  Serious assault  Total  Total  2003
#
#   Unit of measurement  VALUE Source
# 0              Counts    155    CTS
# 1              Counts  61959    CTS
# 2              Counts   3806    CTS
# 3              Counts   2701    CTS
# ...

# %%
df.columns
# Out:
# Index(['Iso3_code', 'Country', 'Region', 'Subregion', 'Indicator', 'Dimension',
#        'Category', 'Sex', 'Age', 'Year', 'Unit of measurement', 'VALUE',
#        'Source'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26114 entries, 0 to 26113
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Iso3_code            26114 non-null  object
#  1   Country              26114 non-null  object
#  2   Region               26114 non-null  object
#  3   Subregion            26114 non-null  object
#  4   Indicator            26114 non-null  object
#  5   Dimension            26114 non-null  object
#  6   Category             26114 non-null  object
#  7   Sex                  26114 non-null  object
#  8   Age                  26114 non-null  object
#  9   Year                 26114 non-null  int64
#  10  Unit of measurement  26114 non-null  object
#  11  VALUE                26114 non-null  object
#  12  Source               26114 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 2.6+ MB

# %%
df['Unit of measurement'].unique()
# Out:
# array(['Counts', 'Rate per 100,000 population'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['Azerbaijan', 'Belgium', 'Bulgaria', 'Bahrain', 'Belarus',
#        'Bermuda', 'Brunei Darussalam', 'Canada', 'Switzerland',
#        'Cameroon', 'Cyprus', 'Germany', 'Denmark', 'Algeria', 'Ecuador',
#        'Finland', 'France', 'United Kingdom (England and Wales)',
#        'United Kingdom (Northern Ireland)', 'United Kingdom (Scotland)',
#        'Greece', 'China, Hong Kong Special Administrative Region',
#        'Croatia', 'Hungary', 'Ireland', 'Japan', 'Kyrgyzstan',
#        'Liechtenstein', 'Sri Lanka', 'Lithuania', 'Latvia', 'Morocco',
#        'Monaco', 'Montenegro', 'Mongolia', 'Mauritius',
#        'Netherlands (Kingdom of the)', 'Norway', 'Portugal',
#        'State of Palestine', 'Qatar', 'Romania', 'Singapore',
#        'Sao Tome and Principe', 'Slovakia', 'Slovenia', 'Sweden',
#        'Eswatini', 'Syrian Arab Republic', 'Türkiye', 'Uganda', 'Ukraine',
#        'United States of America', 'Zimbabwe', 'Armenia', 'Austria',
# ...

# %%
df['Year'].unique()
# Out:
# array([2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022], dtype=int64)

# %%
df_19_22 = df[df['Year'].between(2019,2022,inclusive='both')]

# %%
df_19_22.to_csv('files/df_19_22.csv')

# %%
df_19_22.head(20)
# Out:
#      Iso3_code                           Country    Region  \
# 1591       ALB                           Albania    Europe
# 1592       AND                           Andorra    Europe
# 1593       ARE              United Arab Emirates      Asia
# 1594       ARG                         Argentina  Americas
# 1595       ARM                           Armenia      Asia
# 1596       ATG               Antigua and Barbuda  Americas
# 1597       AUS                         Australia   Oceania
# 1598       AUT                           Austria    Europe
# 1599       AZE                        Azerbaijan      Asia
# 1600       BEL                           Belgium    Europe
# 1601       BGR                          Bulgaria    Europe
# 1602       BHS                           Bahamas  Americas
# 1603       BIH            Bosnia and Herzegovina    Europe
# 1604       BLR                           Belarus    Europe
# 1605       BLZ                            Belize  Americas
# ...

# %%
df_19_22['Dimension'].unique()
# Out:
# array(['by type of offence', 'by relationship to perpetrator'],
#       dtype=object)

# %%
df_19_22[(df_19_22['Country'] == 'Brazil') | (df_19_22['Country'] == 'United States of America')]['VALUE'].nunique()
# Out:
# 36

# %%
df_19_22[(df_19_22['Country'] == 'Brazil')]['VALUE'].nunique()
# Out:
# 16

# %%
df_19_22[(df_19_22['Country'] == 'Brazil') | (df_19_22['Country'] == 'United States of America')].sample(20)
# Out:
#       Iso3_code                   Country    Region  \
# 1607        BRA                    Brazil  Americas
# 16541       BRA                    Brazil  Americas
# 20277       BRA                    Brazil  Americas
# 20637       USA  United States of America  Americas
# 7483        USA  United States of America  Americas
# 20363       USA  United States of America  Americas
# 7306        BRA                    Brazil  Americas
# 16866       USA  United States of America  Americas
# 14782       BRA                    Brazil  Americas
# 21278       BRA                    Brazil  Americas
# 7290        USA  United States of America  Americas
# 1709        BRA                    Brazil  Americas
# 8205        BRA                    Brazil  Americas
# 8118        BRA                    Brazil  Americas
# 1792        USA  United States of America  Americas
# 14865       USA  United States of America  Americas
# 1692        USA  United States of America  Americas
# ...

# %%
df_rate = df_19_22[df_19_22['Unit of measurement'] == 'Rate per 100,000 population']

# %%
df_rate.to_csv('files/df_rate.csv')

# %%
df_rate.head(20)
# Out:
#       Iso3_code                           Country    Region  \
# 14664       ALB                           Albania    Europe
# 14665       AND                           Andorra    Europe
# 14666       ARE              United Arab Emirates      Asia
# 14667       ARG                         Argentina  Americas
# 14668       ARM                           Armenia      Asia
# 14669       ATG               Antigua and Barbuda  Americas
# 14670       AUS                         Australia   Oceania
# 14671       AUT                           Austria    Europe
# 14672       AZE                        Azerbaijan      Asia
# 14673       BEL                           Belgium    Europe
# 14674       BGR                          Bulgaria    Europe
# 14675       BHS                           Bahamas  Americas
# 14676       BIH            Bosnia and Herzegovina    Europe
# 14677       BLR                           Belarus    Europe
# 14678       BLZ                            Belize  Americas
# ...

# %%
df_rate['Sex'].unique()
# Out:
# array(['Total', 'Male', 'Female'], dtype=object)

# %%
df_rate['Category'].unique()
# Out:
# array(['Serious assault', 'Kidnapping', 'Sexual violence',
#        'Sexual violence: Rape', 'Sexual violence: Sexual assault',
#        'Sexual violence: Other acts of sexual violence',
#        'Sexual Exploitation', 'Intimate partner or family member',
#        'Other Perpetrator known to the victim',
#        'Perpetrator unknown to the victim',
#        'Relationship to perpetrator is not known',
#        'Acts intended to induce fear or emotional distress',
#        'Acts intended to induce fear or emotional distress: Cyber-related'],
#       dtype=object)

# %%
df_rate['Indicator'].unique()
# Out:
# array(['Violent offences', 'Victims of serious assault',
#        'Victims of sexual violence'], dtype=object)

# %%
df.columns
# Out:
# Index(['Iso3_code', 'Country', 'Region', 'Subregion', 'Indicator', 'Dimension',
#        'Category', 'Sex', 'Age', 'Year', 'Unit of measurement', 'VALUE',
#        'Source'],
#       dtype='object')
